# %% [markdown]
# <a href="https://colab.research.google.com/github/UsmanArif169/Machine-Learning-Algorithms-/blob/main/elastic_net_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
X,y = load_diabetes(return_X_y=True)
print(X.shape,y.shape)
# Out:
# (442, 10) (442,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2, random_state =2)

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

reg = LinearRegression()
reg.fit(X_train,y_train)

y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
# Ridge regression
# It is used to overcome overfitting by adding lambda term in MSE

from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
reg = Ridge(alpha = 0.1)
reg.fit(X_train,y_train)

y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.45199494197195456

# %%
# Lasso regression


reg = Lasso(alpha = 0.01)
reg.fit(X_train,y_train)

y_pred = reg.predict(X_test)
r2_score = r2_score(y_test,y_pred)
print(r2_score)
# Out:
# 0.44111855963110613

# %%
# ElasticNet

# it is used both ridge and lasso

from sklearn.metrics import r2_score
from sklearn.linear_model import ElasticNet

reg = ElasticNet(alpha = 0.005, l1_ratio= 0.9)
reg.fit(X_train,y_train)

y_pred = reg.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.4531474541554823
